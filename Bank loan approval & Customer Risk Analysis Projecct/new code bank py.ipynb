# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"H:\sales risk analysis project analyst\Bank loan approval & Customer Risk Analysis Projecct\loan_approval_dataset.csv")

# %%
df
# Out:
#       loan_id  dependents      education self_employed  annual_income  \
# 0           1           2       Graduate            No        9600000
# 1           2           0   Not Graduate           Yes        4100000
# 2           3           3       Graduate            No        9100000
# 3           4           3       Graduate            No        8200000
# 4           5           5   Not Graduate           Yes        9800000
# ...       ...         ...            ...           ...            ...
# 4264     4265           5       Graduate           Yes        1000000
# 4265     4266           0   Not Graduate           Yes        3300000
# 4266     4267           2   Not Graduate            No        6500000
# 4267     4268           1   Not Graduate            No        4100000
# 4268     4269           1       Graduate            No        9200000
#
#       requested_loan  loan_term  cibil_score  residential_assets_value  \
# ...

# %%
df.head()
# Out:
#    loan_id  dependents      education self_employed  annual_income  \
# 0        1           2       Graduate            No        9600000
# 1        2           0   Not Graduate           Yes        4100000
# 2        3           3       Graduate            No        9100000
# 3        4           3       Graduate            No        8200000
# 4        5           5   Not Graduate           Yes        9800000
#
#    requested_loan  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# 1        12200000          8          417                   2700000
# 2        29700000         20          506                   7100000
# 3        30700000          8          467                  18200000
# 4        24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   dependents                4269 non-null   int64
#  2   education                 4269 non-null   str
#  3   self_employed             4269 non-null   str
#  4   annual_income             4269 non-null   int64
#  5   requested_loan            4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   str
#  13  dti_ratio                 4269 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                     0
# dependents                  0
# education                   0
# self_employed               0
# annual_income               0
# requested_loan              0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dti_ratio                   0
# total_assets                0
# loan_status_encoded         0
# dtype: int64

# %%
df.describe()
# Out:
#            loan_id   dependents  annual_income  requested_loan    loan_term  \
# count  4269.000000  4269.000000   4.269000e+03    4.269000e+03  4269.000000
# mean   2135.000000     2.498712   5.059124e+06    1.513345e+07    10.900445
# std    1232.498479     1.695910   2.806840e+06    9.043363e+06     5.709187
# min       1.000000     0.000000   2.000000e+05    3.000000e+05     2.000000
# 25%    1068.000000     1.000000   2.700000e+06    7.700000e+06     6.000000
# 50%    2135.000000     3.000000   5.100000e+06    1.450000e+07    10.000000
# 75%    3202.000000     4.000000   7.500000e+06    2.150000e+07    16.000000
# max    4269.000000     5.000000   9.900000e+06    3.950000e+07    20.000000
#
#        cibil_score  residential_assets_value  commercial_assets_value  \
# count  4269.000000              4.269000e+03             4.269000e+03
# mean    599.936051              7.472617e+06             4.973155e+06
# std     172.430401              6.503637e+06             4.388966e+06
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['loan_id', 'dependents', 'education', 'self_employed', 'annual_income',
#        'requested_loan', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status', 'dti_ratio',
#        'total_assets', 'loan_status_encoded'],
#       dtype='str')

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df.groupby('loan_status')['cibil_score'].mean()
# Out:
# loan_status
# Approved    703.461973
# Rejected    429.468072
# Name: cibil_score, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='loan_status', data=df)
plt.title('Loan Approval Status Count')
plt.show()

# %%
df.to_csv('final_loan_data_cleaned.csv', index=False)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='loan_status', y='cibil_score', data=df)
plt.title('Credit Score Distribution by Loan Status')
plt.show()

# %%
df.columns.tolist()
# Out:
# ['loan_id',
#  'dependents',
#  'education',
#  'self_employed',
#  'annual_income',
#  'requested_loan',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status',
#  'dti_ratio',
#  'total_assets',
#  'loan_status_encoded']

# %%
print(df.columns)
# Out:
# Index(['loan_id', 'dependents', 'education', 'self_employed', 'annual_income',
#        'requested_loan', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status', 'dti_ratio',
#        'total_assets', 'loan_status_encoded'],
#       dtype='str')

# %%
# Automatically find the income column
income_col = [col for col in df.columns if 'income' in col.lower()]

if income_col:
    col_name = income_col[0]
    sns.histplot(data=df, x=col_name, hue='loan_status', kde=True)
    plt.title(f'Income Distribution ({col_name}) by Loan Status')
    plt.show()
else:
    print("Could not find an income column. Here are your columns:", df.columns.tolist())
